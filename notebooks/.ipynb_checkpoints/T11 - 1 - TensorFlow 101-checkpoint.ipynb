# %% [markdown]
# # Introducción a TensorFlow

# %%
import tensorflow as tf

# %%
x1 = tf.constant([1,2,3,4,5])
x2 = tf.constant([6,7,8,9,10])

# %%
res = tf.multiply(x1, x2)
res
# Out:
# <tf.Tensor 'Mul:0' shape=(5,) dtype=int32>

# %%
sess = tf.Session()
print(sess.run(res))
sess.close()
# Out:
# [ 6 14 24 36 50]

# %%
with tf.Session() as sess:
    output = sess.run(res)
    print(output)
# Out:
# [ 6 14 24 36 50]

# %%
config = tf.ConfigProto(log_device_placement = True)
config = tf.ConfigProto(allow_soft_placement = True)

# %% [markdown]
# ## Aprendizaje neuronal de las señales de tráfico

# %%
import os
import matplotlib.image as imd
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
def load_ml_data(data_directory):
    dirs = [d for d in os.listdir(data_directory)
           if os.path.isdir(os.path.join(data_directory, d))]
    labels = []
    images = []
    for d in dirs:
        label_dir = os.path.join(data_directory, d)
        file_names = [os.path.join(label_dir, f)
                     for f in os.listdir(label_dir)
                     if f.endswith('.ppm')]
        for f in file_names:
            images.append(imd.imread(f))
            labels.append(int(d))
    
    return images, labels

# %%
main_dir = '../datasets/belgian/'
train_data_dir = os.path.join(main_dir, 'Training')
test_data_dir = os.path.join(main_dir, 'Testing')

# %%
images, labels = load_ml_data(train_data_dir)

# %%
images = np.array(images)

# %%
labels = np.array(labels)

# %%
images[0]
# Out:
# array([[[210, 249, 232],
#         [204, 249, 208],
#         [197, 198, 155],
#         ...,
#         [ 51,  60,  40],
#         [ 54,  64,  44],
#         [ 57,  66,  46]],
#
#        [[209, 250, 236],
#         [212, 255, 217],
#         [200, 196, 156],
#         ...,
#         [ 49,  57,  38],
#         [ 51,  59,  41],
#         [ 53,  60,  42]],
#
#        [[203, 246, 236],
#         [207, 246, 213],
#         [202, 192, 156],
#         ...,
#         [ 47,  53,  35],
#         [ 48,  54,  36],
#         [ 48,  55,  37]],
#
#        ...,
#
#        [[  2,  22,  25],
#         [ 26,  56,  77],
#         [ 71, 140, 159],
#         ...,
#         [ 84,  77,  50],
#         [ 68,  66,  41],
#         [ 56,  64,  44]],
#
#        [[  0,  22,  32],
#         [ 30,  75, 106],
#         [ 87, 176, 198],
#         ...,
#         [ 86,  80,  52],
#         [ 68,  66,  41],
#         [ 55,  63,  42]],
#
#        [[  0,  32,  50],
#         [ 42, 101, 135],
#         [121, 217, 239],
#         ...,
#         [ 87,  80,  52],
#         [ 70,  68,  43],
#         [ 58,  66,  46]]], dtype=uint8)

# %%
labels.ndim
# Out:
# 1

# %%
labels.size
# Out:
# 4575

# %%
len(set(labels))
# Out:
# 62

# %%
images.flags
# Out:
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : True
#   OWNDATA : True
#   WRITEABLE : True
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#   UPDATEIFCOPY : False

# %%
images.itemsize
# Out:
# 8

# %%
images.nbytes
# Out:
# 36600

# %%
images.nbytes / images.itemsize
# Out:
# 4575.0

# %%
plt.hist(labels, len(set(labels)))
plt.show()

# %%
rand_signs = random.sample(range(0, len(labels)), 6)
rand_signs
# Out:
# [1361, 2701, 3101, 479, 1243, 1686]

# %%
for i in range(len(rand_signs)):
    temp_im = images[rand_signs[i]]
    plt.subplot(1,6,i+1)
    plt.axis('off')
    plt.imshow(images[rand_signs[i]])
    plt.subplots_adjust(wspace=0.5)
    plt.show()
    print('Forma:{0}, min:{1}, max:{2}'.format(temp_im.shape, temp_im.min(), temp_im.max()))
# Out:
# Forma:(106, 80, 3), min:6, max:255
# Forma:(75, 79, 3), min:15, max:255
# Forma:(79, 74, 3), min:17, max:255
# Forma:(167, 176, 3), min:0, max:255
# Forma:(350, 196, 3), min:0, max:255
# Forma:(92, 88, 3), min:10, max:255

# %%
unique_labels = set(labels)
plt.figure(figsize=(16,16))
i = 1
for label in unique_labels:
    temp_im = images[list(labels).index(label)]
    plt.subplot(8,8,i)
    plt.axis('off')
    plt.title('Clase {0} ({1})'.format(label, list(labels).count(label)))
    i+=1
    plt.imshow(temp_im)
plt.show()

# %% [markdown]
# # Modelo de Red Neuronal con TensorFlow

# %%
from skimage import transform

# %%
w=9999
h=9999
for image in images:
    if image.shape[0] < h:
        h = image.shape[0]
    if image.shape[1] < w:
        w = image.shape[1]
print('Tamaño mínimo: {0}x{1}'.format(h, w))
# Out:
# Tamaño mínimo: 22x20

# %%
images30 = [transform.resize(image, (30,30)) for image in images]

# %%
images30[0]
# Out:
# array([[[0.72005229, 0.70687582, 0.57784314],
#         [0.52505882, 0.40976471, 0.28803922],
#         [0.52320261, 0.39620915, 0.28581699],
#         ...,
#         [0.19869281, 0.22895425, 0.15163399],
#         [0.18466667, 0.21152941, 0.14058824],
#         [0.18534641, 0.21228758, 0.14169935]],
#
#        [[0.69623529, 0.65879739, 0.53219608],
#         [0.49666667, 0.34654902, 0.23752941],
#         [0.46705882, 0.32098039, 0.22104575],
#         ...,
#         [0.18607843, 0.22137255, 0.14294118],
#         [0.18980392, 0.22901961, 0.1545098 ],
#         [0.19847059, 0.22721569, 0.15901961]],
#
#        [[0.68928105, 0.67254902, 0.53823529],
#         [0.50666667, 0.43901961, 0.32901961],
#         [0.47941176, 0.40849673, 0.30392157],
#         ...,
#         [0.18496732, 0.20588235, 0.13333333],
#         [0.18823529, 0.22019608, 0.14627451],
#         [0.19267974, 0.22366013, 0.15601307]],
#
#        ...,
#
#        [[0.0903268 , 0.12071895, 0.04843137],
#         [0.07627451, 0.11058824, 0.0672549 ],
#         [0.14052288, 0.19150327, 0.1627451 ],
#         ...,
#         [0.05653595, 0.24509804, 0.5127451 ],
#         [0.18823529, 0.39882353, 0.50117647],
#         [0.29777778, 0.33751634, 0.26653595]],
#
#        [[0.10018301, 0.1444183 , 0.10628758],
#         [0.31776471, 0.38933333, 0.35760784],
#         [0.45137255, 0.52281046, 0.53281046],
#         ...,
#         [0.05215686, 0.22686275, 0.50196078],
#         [0.14831373, 0.36470588, 0.53176471],
#         [0.32215686, 0.36584314, 0.29607843]],
#
#        [[0.2950719 , 0.4780915 , 0.51959477],
#         [0.62521569, 0.68972549, 0.75180392],
#         [0.18013072, 0.31163399, 0.51784314],
#         ...,
#         [0.05431373, 0.21830065, 0.48960784],
#         [0.14117647, 0.36054902, 0.52941176],
#         [0.30815686, 0.35163399, 0.27555556]]])

# %%
rand_signs = random.sample(range(0, len(labels)), 6)
rand_signs
for i in range(len(rand_signs)):
    temp_im = images30[rand_signs[i]]
    plt.subplot(1,6,i+1)
    plt.axis('off')
    plt.imshow(temp_im)
    plt.subplots_adjust(wspace=0.5)
    plt.show()
    print('Forma:{0}, min:{1}, max:{2}'.format(temp_im.shape, temp_im.min(), temp_im.max()))
# Out:
# Forma:(30, 30, 3), min:0.050313725490196595, max:0.9811764705882352
# Forma:(30, 30, 3), min:0.04107843137254902, max:0.9926470588235294
# Forma:(30, 30, 3), min:0.0, max:0.5137254901960785
# Forma:(30, 30, 3), min:0.0647058823529412, max:0.996078431372549
# Forma:(30, 30, 3), min:0.11764705882352941, max:0.9930065359477125
# Forma:(30, 30, 3), min:0.06274509803921569, max:1.0

# %%
from skimage.color import rgb2gray

# %%
images30 = np.array(images30)
images30 = rgb2gray(images30)

# %%
rand_signs = random.sample(range(0, len(labels)), 6)
rand_signs
for i in range(len(rand_signs)):
    temp_im = images30[rand_signs[i]]
    plt.subplot(1,6,i+1)
    plt.axis('off')
    plt.imshow(temp_im, cmap='gray')
    plt.subplots_adjust(wspace = 0.5)
    plt.show()
    print('Forma: {0}, min:{1}, max:{2}'.format(temp_im.shape, temp_im.min(), temp_im.max()))
# Out:
# Forma: (30, 30), min:0.14216320522875794, max:0.993444271895425
# Forma: (30, 30), min:0.0, max:0.992319880392157
# Forma: (30, 30), min:0.0450272954248366, max:0.9885502627450977
# Forma: (30, 30), min:0.007097483660130739, max:0.9141043627450978
# Forma: (30, 30), min:0.0, max:0.9869488039215687
# Forma: (30, 30), min:0.08713196078431369, max:0.9101029287581696

# %% [markdown]
# ## Creación del modelo

# %% [markdown]
# Primer paso: Crear los placeholders

# %%
# Tensores
x = tf.placeholder(dtype=tf.float32, shape= [None, 30,30])
y = tf.placeholder(dtype=tf.int32, shape= [None])

# %% [markdown]
# Segundo paso: Construir red neuronal

# %%
# Distribuir los datos desde matrices 30x30 a listas 
images_flat = tf.contrib.layers.flatten(x)

logits = tf.contrib.layers.fully_connected(images_flat, 62, tf.nn.relu)

# Perceptrón multicapa
loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(labels = y, logits=logits))

# Función para optimizar
train_opt = tf.train.AdamOptimizer(learning_rate=0.001).minimize(loss)

# Predicción final
final_pred = tf.argmax(logits, 1)

accuracy = tf.reduce_mean(tf.cast(final_pred, tf.float32))

# %%
images_flat
# Out:
# <tf.Tensor 'Flatten_2/flatten/Reshape:0' shape=(?, 900) dtype=float32>

# %%
logits
# Out:
# <tf.Tensor 'fully_connected_2/Relu:0' shape=(?, 62) dtype=float32>

# %%
loss
# Out:
# <tf.Tensor 'Mean_2:0' shape=() dtype=float32>

# %%
final_pred
# Out:
# <tf.Tensor 'ArgMax_1:0' shape=(?,) dtype=int64>

# %% [markdown]
# ## Entrenamiento del modelo

# %%
tf.set_random_seed(12345)
sess = tf.Session()
sess.run(tf.global_variables_initializer())
for i in range(1201):
    _, accuracy_val = sess.run([train_opt, accuracy],
                                feed_dict={
                                    x: images30,
                                    y: list(labels)
                                })

    _, loss_val = sess.run([train_opt, loss],
                                feed_dict={
                                    x: images30,
                                    y: list(labels)
                                })

    if i%50 == 0:
        print('EPOCH', i)
        print('Eficacia: ', accuracy_val)
        print('Pérdida: ', loss_val)
    # print('Fin del Epoch ', i)
# Out:
# EPOCH 0
# Eficacia:  32.215736
# Pérdida:  4.001775
# EPOCH 50
# Eficacia:  36.08306
# Pérdida:  2.2638724
# EPOCH 100
# Eficacia:  35.73224
# Pérdida:  1.9262899
# EPOCH 150
# Eficacia:  35.614643
# Pérdida:  1.764695
# EPOCH 200
# Eficacia:  35.393005
# Pérdida:  1.6625756
# EPOCH 250
# Eficacia:  35.299236
# Pérdida:  1.5901123
# EPOCH 300
# Eficacia:  35.19869
# Pérdida:  1.5354819
# EPOCH 350
# Eficacia:  35.08721
# Pérdida:  1.4923003
# EPOCH 400
# Eficacia:  35.002625
# Pérdida:  1.4569734
# EPOCH 450
# Eficacia:  34.897488
# Pérdida:  1.4273556
# EPOCH 500
# Eficacia:  34.831474
# Pérdida:  1.4020131
# EPOCH 550
# Eficacia:  34.78754
# Pérdida:  1.3799529
# EPOCH 600
# Eficacia:  34.73552
# Pérdida:  1.3605698
# EPOCH 650
# Eficacia:  34.64896
# Pérdida:  1.3433789
# EPOCH 700
# Eficacia:  34.5259
# Pérdida:  1.327975
# EPOCH 750
# Eficacia:  34.380547
# Pérdida:  1.3139927
# EPOCH 800
# Eficacia:  34.25836
# Pérdida:  1.301233
# EPOCH 850
# Eficacia:  34.18011
# Pérdida:  1.2895848
# EPOCH 900
# Eficacia:  34.07366
# Pérdida:  1.2788823
# EPOCH 950
# Eficacia:  33.95388
# Pérdida:  1.2689956
# EPOCH 1000
# Eficacia:  33.784042
# Pérdida:  1.2598257
# EPOCH 1050
# Eficacia:  33.711258
# Pérdida:  1.2512827
# EPOCH 1100
# Eficacia:  33.521748
# Pérdida:  1.2433066
# EPOCH 1150
# Eficacia:  33.34929
# Pérdida:  1.2358528
# EPOCH 1200
# Eficacia:  33.244152
# Pérdida:  1.2288555

# %% [markdown]
# ## Validación del modelo

# %%
sample_idx = random.sample(range(len(images30)), 16)
sample_images = [images30[i] for i in sample_idx]
sample_labels = [labels[i] for i in sample_idx]

# %%
sample_labels
# Out:
# [32, 32, 32, 22, 28, 21, 38, 43, 53, 4, 39, 22, 53, 40, 40, 53]

# %%
prediction = sess.run([final_pred], feed_dict={
    x: sample_images
})

# %%
prediction
# Out:
# [array([32, 32, 32, 22, 28,  1, 38, 40, 53,  7, 39, 22, 53, 40, 40, 53],
#        dtype=int64)]

# %%
plt.figure(figsize=(16,9))
for i in range(len(sample_images)):
    truth = sample_labels[i]
    predi = prediction[0][i]
    plt.subplot(4,4, i+1)
    plt.axis('off')
    color = 'green' if truth==predi else 'red'
    plt.text(32, 15, 'Real:         {0}\nPredicción:{1}'.format(truth, predi),
            fontsize=14, color = color)
    plt.imshow(sample_images[i], cmap = 'gray')
plt.show()

# %% [markdown]
# ## Dataset de prueba

# %%
test_images, test_labels = load_ml_data(test_data_dir)

# %%
test_images30 = [transform.resize(im, (30,30)) for im in test_images]

# %%
len(test_images30)
# Out:
# 2520

# %%
test_images30 = rgb2gray(np.array(test_images30))

# %%
prediction = sess.run([final_pred], feed_dict={x:test_images30})[0]

# %%
match_count = sum([int(l0 == lp) for l0, lp in zip(test_labels, prediction)])
match_count
# Out:
# 1638

# %%
acc = match_count/len(test_labels)*100
print('Eficacia de la red neuronal: {:.2f}'.format(acc))
# Out:
# Eficacia de la red neuronal: 65.00
