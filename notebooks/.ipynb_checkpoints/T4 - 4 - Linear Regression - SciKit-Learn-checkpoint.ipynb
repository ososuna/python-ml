# %% [markdown]
# # Regresión lineal en Python

# %% [markdown]
# ## El paquete scikit-learn para regresión lineal y la selección de rasgos

# %%
from sklearn.feature_selection import RFE
from sklearn.svm import SVR
import pandas as pd
import numpy as np
from IPython.display import Image

# %%
data = pd.read_csv('../datasets/ads/Advertising.csv')

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
feature_cols = ['TV', 'Radio', 'Newspaper']

# %%
# Nombre de las columnas que en principio serán variables predictoras
X = data[feature_cols]
# Variable a predecir
Y = data['Sales']

# %%
estimator = SVR(kernel='linear')
# Se indica que se utilizarán dos variables y que se hará en un solo paso
selector = RFE(estimator, 2, step=1)
selector = selector.fit(X, Y)

# %%
# Obtener la lista de variables seleccionadas
selector.support_
# Out:
# array([ True,  True, False])

# %%
# Las variables seleccionadas aparecen con ranking = 1, las subsiguientes se ordenan de manera decreciente
selector.ranking_
# Out:
# array([1, 1, 2])

# %%
# Regresión lineal automática de scikit learn
from sklearn.linear_model import LinearRegression

# %%
X_pred = X[['TV', 'Radio']]

# %%
lm = LinearRegression()
lm.fit(X_pred, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
# Intercepto
lm.intercept_
# Out:
# 2.9210999124051362

# %%
# Coeficientes
lm.coef_
# Out:
# array([0.04575482, 0.18799423])

# %%
# Valor de R^2
lm.score(X_pred, Y)
# Out:
# 0.8971942610828956

# %% [markdown]
# ## Variables categóricas

# %%
Image(filename='resources/variables-categoricas-01.png')

# %% [markdown]
# Hasta ahora hemos asumido que todas las variables predictoras para elaborar el modelo son cuantitativas, o bien numéricas.

# %% [markdown]
# Sin embargo, muchas veces al elaborar el modelo el dataset del cual partimos tiene variables categóricas o cualitativas. En muchos casos pueden tener un impacto más que significativo en el resultado del modelo que queremos elaborar.

# %%
Image(filename='resources/variables-categoricas-02.png')

# %% [markdown]
# Cuando una de las x es categórica, entonces se define otra variable.

# %% [markdown]
# En el caso de tener una variable categórica con 3 niveles:

# %%
Image(filename='resources/variables-categoricas-03.png')
